# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import precision_recall_fscore_support

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import RandomizedSearchCV

import pickle
import os
# %matplotlib inline

# %%
from sklearn import metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %%
# create folder to save models
models_loc='models/'
if not os.path.exists(models_loc):
    os.makedirs(models_loc)

# %%
# define parameters
interval= True
mov_avg=False
make_gridsearch=False

make_kfold=False 
K_folds=5

# %%
# # read files
# logs=pd.read_csv('data_cleaned/logs_combined.csv')
# stack_logs=pd.read_csv('data_cleaned/stack_logs_combined.csv')
# stack_df=pd.read_csv('data_cleaned/stacks_combined.csv')
# stack_section2=pd.read_csv('data_cleaned/2D_section2_stack.csv')
# read data
logs = pd.read_csv("Data/logs_7wells.csv")
stack_logs=pd.read_csv('data/seismic_7wells.csv')
stack_section2=pd.read_csv('data/section_2D_2.csv')

WS_level=0.8
logs['Target']=0
logs.loc[logs['Water Saturation']<=WS_level, 'Target']=1

# %%
stack_logs.columns
# Out:
# Index(['Time', 'Seismic', 'log_ID', 'QuadrTrace', 'SecDerInstAmpl',
#        'Integrated', 'AWCP', 'Der', 'AWF', 'DomF', 'InstF', 'SecDer', 'AmpEnv',
#        'AppPolr'],
#       dtype='object')

# %%
seismic_att_names=['Time','AmpEnv', 'AppPolr', 'AWCP', 'AWF', 'Der',
       'DomF', 'InstF', 'Integrated', 'QuadrTrace', 'SecDer', 'SecDerInstAmpl', 
       'Seismic']

# %%
logs.describe()
# Out:
#                Time       Density        P_wave      Porosity        V_clay  \
# count  75758.000000  75758.000000  75758.000000  75758.000000  75758.000000
# mean    2231.724908      2.259806   2623.788348      0.131551      0.643055
# std      792.450806      0.254068    625.932406      0.052663      0.139405
# min      514.875700      1.254200     69.095500      0.000000      0.000000
# 25%     1623.530175      2.085200   2170.043700      0.088200      0.613300
# 50%     2295.511500      2.258500   2485.396000      0.121300      0.667600
# 75%     2866.009375      2.481600   2997.033275      0.162700      0.717900
# max     3693.633300      3.069000   6082.184100      0.573800      1.000000
#
#        Water Saturation           Imp        Target
# count      75758.000000  75758.000000  75758.000000
# mean           0.993751   6058.714313      0.011722
# std            0.054622   2056.542731      0.107630
# min            0.001000    173.482041      0.000000
# 25%            1.000000   4524.402431      0.000000
# 50%            1.000000   5609.819003      0.000000
# 75%            1.000000   7465.468304      0.000000
# max            1.000000  17780.676767      1.000000

# %% [markdown]
# ### Train algorithms on small interwal

# %% [markdown]
#  . |6507/3-6 | 6507/6-4A | 6507/5-5 | 6507/3-9S | 6507/2-4 | 6507/2-2 | 6507/2-1
#  ---|---|---|---|---|---|---|---
# from| 1300| 1050| 2585| 2650| 2670| 2666| 2674
# to| 1352| 1200| 2734| 2800 |2800 |2800 |2840

# %%
# select df only in this intervals

if interval==True:

    sub_logs=logs[(logs['log_ID']=='6507_3-6') & (logs['Time']>=1300) & (logs['Time']<=1352)].append(
        logs[(logs['log_ID']=='6507_6-4A') & (logs['Time']>=1050) & (logs['Time']<=1200)]).append(
        logs[(logs['log_ID']=='6507_5-5') & (logs['Time']>=2585) & (logs['Time']<=2734)]).append(
        logs[(logs['log_ID']=='6507_3-9S') & (logs['Time']>=2650) & (logs['Time']<=2800)]).append(
        logs[(logs['log_ID']=='6507_2-4') & (logs['Time']>=2670) & (logs['Time']<=2800)]).append(
        logs[(logs['log_ID']=='6507_2-2') & (logs['Time']>=2666) & (logs['Time']<=2800)]).append(
        logs[(logs['log_ID']=='6507_2-1') & (logs['Time']>=2674) & (logs['Time']<=2840)]).reset_index(drop=True)
    
else:
    # select df only in this intervals 2D-K65, 2D-BCU, 2D-bottom

    sub_logs=logs[(logs['Horison']=='2D-K65') | (logs['Horison']=='2D-BCU')| 
         (logs['Horison']=='2D-bottom')| (logs['Horison'].isna())]

# %%
plt.plot(sub_logs['Water Saturation'],-sub_logs['Time'],  '.')

# %%
(sub_logs['Water Saturation']<WS_level).sum(), sub_logs.shape[0]
# Out:
# (361, 5287)

# %% [markdown]
# #### Add moving average (Yes/No)

# %%
# 
def opposite_mov_avg(data):
    
    data_1=(data+data.shift(1))/2
    data_1=data.append(data_1.dropna()).sort_values('Time').reset_index(drop=True)
    data_2=(data_1+data_1.shift(1))/2
    data_2=data_1.append(data_2.dropna()).sort_values('Time').reset_index(drop=True)
    return data_2

# %%
count=0
stack_logs_extra_points=[]
for log_id in stack_logs['log_ID'].value_counts().index.to_list():
    
    df_extra_points=opposite_mov_avg(stack_logs[stack_logs['log_ID']==log_id][seismic_att_names])
    df_extra_points['log_ID']=log_id
    
    if count==0:
        stack_logs_extra_points=df_extra_points
    else:
        stack_logs_extra_points=stack_logs_extra_points.append(df_extra_points)
    
    count=count+1

# %%
stack_logs_extra_points['log_ID'].value_counts()
# Out:
# 6507_2-1     3701
# 6507_2-2     3501
# 6507_2-4     3173
# 6507_3-9S    2801
# 6507_3-6      794
# 6507_6-4A     794
# 6507_5-5      794
# Name: log_ID, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.plot(stack_logs_extra_points[stack_logs_extra_points['log_ID']=='6507_2-1']['Time'], stack_logs_extra_points[stack_logs_extra_points['log_ID']=='6507_2-1']['Seismic'], '-g');
plt.plot(stack_logs[stack_logs['log_ID']=='6507_2-1']['Time'], stack_logs[stack_logs['log_ID']=='6507_2-1']['Seismic'], '-r', alpha=0.5);

# %%
if mov_avg==True:
    sub_logs['Time_rounded']=np.round(sub_logs['Time']/1)*1
    sub_logs=sub_logs.groupby(['log_ID','Time_rounded']).mean().reset_index().drop('Time', axis=1).rename(columns={'Time_rounded': 'Time'})
    sub_logs['Target']=0
    sub_logs.loc[sub_logs['Water Saturation']<=0.95, 'Target']=1
    
    print(sub_logs.shape, stack_logs_extra_points.shape)
    
    sub_logs=pd.merge(sub_logs,stack_logs_extra_points, how='inner', on=['log_ID','Time']).sort_values(['log_ID','Time'])
    
    #features=[ 'Density', 'P_wave',  'Imp', 'Stack',  'V_clay']#'Porosity',
    features=['AmpEnv',  'AWCP', 'AWF', 'Der',
       'DomF', 'InstF', 'Integrated', 'QuadrTrace', 'SecDer', 'SecDerinstAmpl', 'Imp']
    #features= ['Stack', 'Imp', 'AmpEnv', 'AppPolr', 'AWF', 'Der', 'DomF', 'InstF', 'Integrated']
else: 
    features=[ 'Density', 'P_wave',  'Imp', 'V_clay']#, 'Porosity'

# %%
sub_logs.shape
# Out:
# (5287, 10)

# %%
sub_logs.columns
# Out:
# Index(['Time', 'Density', 'P_wave', 'Porosity', 'V_clay', 'Water Saturation',
#        'log_ID', 'Horison', 'Imp', 'Target'],
#       dtype='object')

# %%
sub_logs[sub_logs['log_ID']=='6507_2-1']
# Out:
#            Time  Density     P_wave  Porosity  V_clay  Water Saturation  \
# 3758  2674.0835   2.4755  3077.7834    0.1435  0.5941               1.0
# 3759  2674.1855   2.4768  3082.6553    0.1371  0.5931               1.0
# 3760  2674.2876   2.4670  3065.2051    0.1345  0.5883               1.0
# 3761  2674.3906   2.4092  3036.5767    0.1579  0.5128               1.0
# 3762  2674.4944   2.4003  3027.1367    0.1643  0.5045               1.0
# ...         ...      ...        ...       ...     ...               ...
# 5282  2839.5256   2.4407  3021.5254    0.1566  0.5741               1.0
# 5283  2839.6372   2.4411  3008.4778    0.1537  0.5834               1.0
# 5284  2839.7488   2.4543  3008.4778    0.1518  0.6050               1.0
# 5285  2839.8599   2.4660  3012.2029    0.1522  0.6216               1.0
# 5286  2839.9702   2.4777  3015.9346    0.1525  0.6381               1.0
#
#         log_ID  Horison          Imp  Target
# 3758  6507_2-1  2D-mid2  7619.052807       0
# 3759  6507_2-1  2D-mid2  7635.120647       0
# 3760  6507_2-1  2D-mid2  7561.860982       0
# 3761  6507_2-1  2D-mid2  7315.720586       0
# 3762  6507_2-1  2D-mid2  7266.036221       0
# ...        ...      ...          ...     ...
# 5282  6507_2-1   2D-K65  7374.637044       0
# 5283  6507_2-1   2D-K65  7343.995158       0
# 5284  6507_2-1   2D-K65  7383.707065       0
# 5285  6507_2-1   2D-K65  7428.092351       0
# 5286  6507_2-1   2D-K65  7472.581158       0
#
# [1529 rows x 10 columns]

# %%
stack_logs['log_ID'].value_counts()
# Out:
# 6507_2-1     926
# 6507_2-2     876
# 6507_2-4     794
# 6507_3-6     794
# 6507_5-5     794
# 6507_6-4A    794
# 6507_3-9S    701
# Name: log_ID, dtype: int64

# %%
stack_logs[stack_logs['log_ID']=='6507_3-9S']
# Out:
#         Time       Seismic     log_ID  QuadrTrace  SecDerInstAmpl  \
# 1720     0.0  9.384670e-08  6507_3-9S   -0.001864        0.000002
# 1721     4.0 -3.753870e-08  6507_3-9S   -0.001591        0.000002
# 1722     8.0  3.753870e-08  6507_3-9S   -0.001873        0.000002
# 1723    12.0  7.507730e-08  6507_3-9S   -0.001603       -0.000002
# 1724    16.0 -7.507730e-08  6507_3-9S   -0.001882        0.000002
# ...      ...           ...        ...         ...             ...
# 2416  2784.0 -8.279800e-01  6507_3-9S   -0.383181       -0.002736
# 2417  2788.0 -4.793360e-01  6507_3-9S   -0.665601       -0.006272
# 2418  2792.0 -9.287790e-02  6507_3-9S   -0.634270       -0.005420
# 2419  2796.0  2.021190e-01  6507_3-9S   -0.519607        0.002647
# 2420  2800.0  3.575280e-01  6507_3-9S   -0.083510        0.008265
#
#         Integrated      AWCP           Der        AWF     DomF      InstF  \
# 1720  1.146010e-07  0.000575 -1.313850e-07   0.000812  20.5078   0.407303
# 1721  9.488930e-08  0.000575 -1.313850e-07  -0.000837  20.5078  -0.421570
# 1722  1.476410e-07  0.000575  7.507730e-08   0.000868  20.5078   0.433772
# 1723  2.355870e-07  0.000575  3.753870e-08  -0.000896  20.5078  -0.450069
# 1724  1.712700e-07  0.000575 -1.501550e-07   0.000913  20.5078   0.454490
# ...            ...       ...           ...        ...      ...        ...
# 2416 -1.437930e+00 -0.827870  1.597080e-01  19.180300  29.2969  20.944400
# 2417 -1.953330e+00 -0.408720  3.486440e-01  16.100400  29.2969  21.691600
# 2418 -2.088590e+00 -0.045844  3.864580e-01   7.511970  29.2969  15.585200
# 2419 -1.905970e+00  0.030192  2.949970e-01  -0.049926  29.2969  -0.189041
# 2420 -1.513900e+00  0.000600  1.554090e-01  -0.674969  29.2969  -3.782550
#
#             SecDer    AmpEnv       AppPolr
# 1720  0.000000e+00  0.001994  1.994430e-03
# 1721  0.000000e+00  0.001985 -3.753870e-08
# 1722  2.064630e-07  0.002001  2.001490e-03
# 1723 -3.753870e-08  0.001991  7.507730e-08
# 1724 -1.876930e-07  0.002009 -2.009120e-03
# ...            ...       ...           ...
# 2416  2.549340e-01  0.915771 -9.157710e-01
# 2417  1.889360e-01  0.742242 -7.422420e-01
# 2418  3.781320e-02  0.481995 -4.819950e-01
# 2419 -9.146080e-02  0.264099 -2.640990e-01
# 2420 -1.395880e-01  0.178443 -1.784430e-01
#
# [701 rows x 14 columns]

# %%
plt.plot( sub_logs['Water Saturation'],-sub_logs['Time'], '.')

# %%
(sub_logs['Water Saturation']<1).sum(), sub_logs.shape[0]
# Out:
# (418, 5287)

# %% [markdown]
# New 3 well on proposed intervals don't have oil (Water Saturation==1). log'6507_5-5' has oil on 3230 up to 3266

# %%
logs[(logs['log_ID']=='6507_5-5') & (logs['Water Saturation']<1.0)]
# Out:
#          Time  Density   P_wave  Porosity  V_clay  Water Saturation    log_ID  \
# 75158  3230.0   2.6212  86.1755    0.0860  0.7564            0.9974  6507_5-5
# 75159  3234.0   2.3672  79.2598    0.1682  0.0545            0.0815  6507_5-5
# 75160  3238.0   2.3693  75.4672    0.1604  0.0602            0.0448  6507_5-5
# 75161  3242.0   2.3687  75.4699    0.1601  0.0652            0.0504  6507_5-5
# 75162  3246.0   2.4287  71.4300    0.1256  0.0670            0.1406  6507_5-5
# 75163  3250.0   2.4472  71.0303    0.1153  0.0696            0.2849  6507_5-5
# 75164  3254.0   2.3816  77.9391    0.1602  0.0745            0.2734  6507_5-5
# 75165  3258.0   2.3854  77.4561    0.1585  0.0620            0.2992  6507_5-5
# 75166  3262.0   2.4949  76.2368    0.0853  0.3599            0.9099  6507_5-5
# 75167  3266.0   2.6242  71.8005    0.0526  0.3944            0.9964  6507_5-5
#
#       Horison         Imp  Target
# 75158     NaN  225.883221       0
# 75159     NaN  187.623799       1
# 75160     NaN  178.804437       1
# 75161     NaN  178.765552       1
# 75162     NaN  173.482041       1
# 75163     NaN  173.825350       1
# 75164     NaN  185.619761       1
# 75165     NaN  184.763781       1
# 75166     NaN  190.203192       0
# 75167     NaN  188.418872       0

# %%
test_df=sub_logs[sub_logs['log_ID']=='6507_2-2']
train_df=sub_logs[~(sub_logs['log_ID']=='6507_2-2')]

# %%
train_df['log_ID'].value_counts()
# Out:
# 6507_2-1     1529
# 6507_3-9S    1281
# 6507_2-4     1232
# 6507_6-4A      38
# 6507_5-5       38
# 6507_3-6       13
# Name: log_ID, dtype: int64

# %%
test_df['log_ID'].value_counts()
# Out:
# 6507_2-2    1156
# Name: log_ID, dtype: int64

# %%
features
# Out:
# ['Density', 'P_wave', 'Imp', 'V_clay']

# %%
X=train_df[features]
Y=train_df['Target']
X_train, X_val, y_train, y_val = train_test_split(X, Y, test_size=0.3, random_state=42)
X_test=test_df[features]
y_test=test_df['Target']

# %%
X_train.shape
# Out:
# (2891, 4)

# %%
(132+306)
# Out:
# 438

# %%
X_val.shape
# Out:
# (1240, 4)

# %%
train_df.shape
# Out:
# (4131, 10)

# %%
X_test.shape
# Out:
# (1156, 4)

# %%
# find numerical and catoegorical column names
numerical_ix = X.select_dtypes(include=['int64', 'float64']).columns
categorical_ix = X.select_dtypes(include=['object', 'bool']).columns
print (numerical_ix)
print (categorical_ix)
# Out:
# Index(['Density', 'P_wave', 'Imp', 'V_clay'], dtype='object')
# Index([], dtype='object')

# %%
def prec_recall_report(y_true, y_pred):
    
    prec, recall, fscore, support = precision_recall_fscore_support(y_true, y_pred, average='binary')    
        
    print ('Precision: ', prec)
    print ('Recall: ', recall)
    print ('F-score: ', fscore)

# %%
def f1_score_eval(y_true, y_pred):
    prec, recall, fscore, support = precision_recall_fscore_support(y_true, y_pred, average='binary') 
    return fscore

# %%
def prec_recall_fscore_train_val_test(clf, X_train, y_train, X_val, y_val, X_test, y_test):
    y_train_pred=clf.predict(X_train)
    y_val_pred=clf.predict(X_val)
    y_test_pred=clf.predict(X_test)

    print ('Precision/ Recall/ F-score on train set : \n')
    prec_recall_report(y_train, y_train_pred)

    if (X_train.shape!=X_val.shape) or ~(X_train==X_val).all().all():
        print ('\n Precision/ Recall/ F-score on validation set : \n')
        prec_recall_report(y_val, y_val_pred)

    print ('\n Precision/ Recall/ F-score on test set : \n')
    prec_recall_report(y_test, y_test_pred)

    
    return y_train_pred, y_val_pred, y_test_pred

# %%
def real_predicted(X_train, y_train, y_train_pred, X_val, y_val, y_val_pred, X_test, y_test, y_test_pred, title_text, logs=train_df, logs_4=test_df):
    fig, ax = plt.subplots(1,3,figsize=(15,8))


    #plot y_train Vs y_train_pred 
    ax[0].plot(y_train,-logs.loc[X_train.index.to_list()]['Time'], 'b.' , alpha=0.5)
    ax[0].plot(y_train_pred+0.015,-logs.loc[y_train.index.to_list()]['Time'], 'r.' , alpha=0.5)
    ax[0].legend(['original', 'predicted']);
    ax[0].set_xlabel('1-oil / 0-otherwise');
    ax[0].set_ylabel('Time');
    ax[0].set_title('train set'); 
    
    if (X_train.shape!=X_val.shape) or ~(X_train==X_val).all().all():
        #plot y_val Vs y_val_pred 
        ax[1].plot(y_val,-logs.loc[X_val.index.to_list()]['Time'], 'b.' , alpha=0.5)
        ax[1].plot(y_val_pred+0.015,-logs.loc[y_val.index.to_list()]['Time'], 'r.' , alpha=0.5)
        ax[1].legend(['original', 'predicted']);
        ax[1].set_xlabel('1-oil / 0-otherwise');
        ax[1].set_ylabel('Time');
        ax[1].set_title('validation set'); 

    #plot y_test VS y_test_pred
    ax[2].plot(y_test,-logs_4['Time'], 'b.' , alpha=0.5)
    ax[2].plot(y_test_pred+0.015,-logs_4['Time'], 'r.' , alpha=0.5)
    ax[2].legend(['original', 'predicted']);
    ax[2].set_title('test set');    
    ax[2].set_xlabel('1-oil / 0-otherwise');
    
    fig.suptitle(title_text, fontsize=16)

# %%
def predict_section(df1, method_name, method, features=features):
    df1['Pred']=method.predict(df1[features])

    df2=df1[['Trace','Time', 'Pred']].groupby(['Time', 'Trace'])['Pred'].aggregate('first').unstack()
    plt.figure(figsize=(20, 10))
    plt.title (method_name)
    ax = sb.heatmap(df2,vmin=0, vmax=1, cmap="YlGnBu")

# %%
def output_function(clf, clf_name, X_train, y_train, X_val, y_val, X_test, y_test):
    y_train_pred, y_val_pred, y_test_pred=prec_recall_fscore_train_val_test(clf, 
                                                                        X_train, y_train, 
                                                                        X_val, y_val, 
                                                                        X_test, y_test)
    
    real_predicted(X_train, y_train, y_train_pred, X_val, y_val, y_val_pred, X_test, y_test, y_test_pred, clf_name)
    if mov_avg== False:
        predict_section(stack_section2.dropna(), '2D section1 - '+clf_name ,  clf )

# %%
def grid_search_function(clf, parameters, X_train, y_train):
    
    cv = GridSearchCV(clf,  param_grid=parameters, scoring = 'f1')
    cv.fit(X_train, y_train)
    print (cv.best_params_)
    
    return cv

# %%
def kfold_gridsearch_function(clf, parameters, X, Y, K_folds):
    
    cv= RepeatedStratifiedKFold(n_splits=K_folds, n_repeats=3, random_state=1)
    search = GridSearchCV(clf, parameters, scoring='f1', n_jobs=-1, cv=cv)
    result = search.fit(X, Y)
    print('Best Hyperparameters: %s' % result.best_params_, '\n')
    print('Mean test score: %s' % result.best_score_, '\n')
    print('Std test score: %s' % result.cv_results_['std_test_score'][result.cv_results_['rank_test_score']==1].tolist()[0], '\n')
    
    return result

# %%
t = [('cat', OneHotEncoder(drop='first'), categorical_ix), 
     ('num',StandardScaler(), numerical_ix)]
col_transform = ColumnTransformer(transformers=t)

# %% [markdown]
# ## Define algorithms and hyper parameters

# %%
# Logistic regression
log_reg = Pipeline([
    ('prep',col_transform), 
    ('clf', LogisticRegression(random_state=42))
    ])

log_reg_params = {
        'clf__solver': ['newton-cg', 'lbfgs', 'liblinear'],
        'clf__penalty':['l2', 'l1'],
        'clf__C':[100, 10, 1.0, 0.1, 0.01]
    }


# Gaussian Naive Bayes 
gnb = Pipeline([
    ('prep',col_transform), 
    ('clf', GaussianNB())
    ])

gnb_params= {
        #'clf__priors': [None],
        'clf__var_smoothing': [0.00000001, 0.000000001, 0.00000001]
    }

# Support Vector Machine
svm=Pipeline([
    ('prep',col_transform), 
    ('clf', SVC(random_state=42))
    ])

svm_params = {
        'clf__kernel':['poly', 'rbf', 'sigmoid'],
        'clf__gamma': ['scale'],
        'clf__C':[50, 10, 1.0, 0.1, 0.01]
    }

# gradient boodting classifier
gbc=Pipeline([
    ('prep',col_transform), 
    ('clf', GradientBoostingClassifier(random_state=42))
    ])


gbc_params = {
        'clf__n_estimators': [10, 100, 1000],
        'clf__learning_rate': [0.001, 0.01, 0.1],
        'clf__subsample':[0.5, 0.7, 1.0], 
        'clf__max_depth': [3, 7, 9]
    }

mlpc= Pipeline([
    ('prep',col_transform), 
    ('clf', MLPClassifier(random_state=1))
     ])

mlpc_params = {
        'clf__hidden_layer_sizes': [(10,30,10),(20,)],
        'clf__activation': ['tanh', 'relu'],
        'clf__solver': ['sgd', 'adam'],
        'clf__alpha': [0.0001, 0.05],
        'clf__learning_rate': ['constant','adaptive']
    }

# %% [markdown]
# ## 1 Logistic regression

# %% [markdown]
# ### 1.1 No parameters tuning

# %%
# Logistic Regression
log_reg = Pipeline([
    ('prep',col_transform), 
    ('clf', LogisticRegression())
    ])

log_reg.fit(X_train, y_train);

# %%
X_test.columns
# Out:
# Index(['Density', 'P_wave', 'Imp', 'V_clay'], dtype='object')

# %%
features
# Out:
# ['Density', 'P_wave', 'Imp', 'V_clay']

# %%
output_function(log_reg, 'Log Reg', X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.8928571428571429
# Recall:  0.9009009009009009
# F-score:  0.8968609865470852
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.8556701030927835
# Recall:  0.9120879120879121
# F-score:  0.8829787234042552
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.6774193548387096
# Recall:  0.875
# F-score:  0.7636363636363636

# %% [markdown]
# ### 1.2 Grid Search for Hyperparameters tuning on Train / Validation / Test (Logistic regression)

# %%
if make_gridsearch==True:
    cv=grid_search_function(log_reg, log_reg_params, X_train, y_train)
    output_function(cv, 'Log Reg', X_train, y_train, X_val, y_val, X_test, y_test)
    
    filename = 'log_reg_classifier_tvt.pkl'
    pickle.dump(cv, open(models_loc+filename, 'wb'))
# Out:
# {'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.9327354260089686
# Recall:  0.9369369369369369
# F-score:  0.9348314606741573
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.9340659340659341
# Recall:  0.9340659340659341
# F-score:  0.9340659340659341
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.7857142857142857
# Recall:  0.9166666666666666
# F-score:  0.8461538461538461

# %% [markdown]
# ### 1.3 KFold and Grid Search (Logistic Regression)

# %%
if make_kfold==True:
    result=kfold_gridsearch_function(log_reg, log_reg_params, X, Y, K_folds)
    output_function(result, 'Log Reg', X, Y, X, Y, X_test, y_test)
    
    filename = 'log_reg_classifier_kfold.pkl'
    pickle.dump(result, open(models_loc+filename, 'wb'))
# Out:
# Best Hyperparameters: {'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
#
# Mean test score: 0.9302402934903193
#
# Std test score: 0.014414793304851075
#
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.9272151898734177
# Recall:  0.9361022364217252
# F-score:  0.931637519872814
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.7857142857142857
# Recall:  0.9166666666666666
# F-score:  0.8461538461538461

# %% [markdown]
# ## 2. Gaussian Naive Bayes

# %% [markdown]
# ### 2.1 No parameters tuning

# %%
gnb.fit(X_train, y_train)
output_function(gnb, 'Gaussian Naive Bayes', X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.8223938223938224
# Recall:  0.9594594594594594
# F-score:  0.8856548856548856
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.8018018018018018
# Recall:  0.978021978021978
# F-score:  0.8811881188118812
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.6133333333333333
# Recall:  0.9583333333333334
# F-score:  0.7479674796747966

# %% [markdown]
# ### 2.2 Grid search for Gaussian Naive Bayes hyperparams on Train/ Validation / Test

# %%
if make_gridsearch==True:
    cv=grid_search_function(gnb, gnb_params,X_train, y_train)
    output_function(cv, 'Gaussian Naive Bayes', X_train, y_train, X_val, y_val, X_test, y_test)
    
    #save model to file
    filename = 'gnb_classifier_tvt.pkl'
    pickle.dump(cv, open(models_loc+filename, 'wb'))
# Out:
# {'clf__var_smoothing': 1e-08}
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.8223938223938224
# Recall:  0.9594594594594594
# F-score:  0.8856548856548856
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.8018018018018018
# Recall:  0.978021978021978
# F-score:  0.8811881188118812
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.6133333333333333
# Recall:  0.9583333333333334
# F-score:  0.7479674796747966

# %% [markdown]
# ### 2.3 Kfold+GridSEarch (Gaussian Naive Bayes)

# %%
if make_kfold==True:
    result=kfold_gridsearch_function(gnb, gnb_params, X, Y, K_folds)
    output_function(result, 'Gaussian Naive Bayes', X, Y, X, Y, X_test, y_test)
    
    filename = 'gnb_classifier_kfold.pkl'
    pickle.dump(result, open(models_loc+filename, 'wb'))
# Out:
# Best Hyperparameters: {'clf__var_smoothing': 1e-08}
#
# Mean test score: 0.891715156366115
#
# Std test score: 0.023089588027388416
#
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.8342541436464088
# Recall:  0.9648562300319489
# F-score:  0.8948148148148147
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.6216216216216216
# Recall:  0.9583333333333334
# F-score:  0.7540983606557377

# %% [markdown]
# ## 3. Support Vector Machine

# %% [markdown]
# ### 3.1 No parameters tuning

# %%
svm.fit(X_train, y_train)
output_function(svm, 'SVM', X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.954337899543379
# Recall:  0.9414414414414415
# F-score:  0.9478458049886621
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.9772727272727273
# Recall:  0.945054945054945
# F-score:  0.9608938547486033
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.7076923076923077
# Recall:  0.9583333333333334
# F-score:  0.8141592920353983

# %% [markdown]
# ### 3.2 Grid search SVM (Train/Validation/Test)

# %%
if make_gridsearch==True:
    cv=grid_search_function(svm, svm_params, X_train, y_train)
    output_function(cv, 'SVM', X_train, y_train, X_val, y_val, X_test, y_test)
    
    filename = 'svm_classifier_tvt.pkl'
    pickle.dump(cv, open(models_loc+filename, 'wb'))
# Out:
# {'clf__C': 1.0, 'clf__gamma': 'scale', 'clf__kernel': 'rbf'}
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.954337899543379
# Recall:  0.9414414414414415
# F-score:  0.9478458049886621
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.9772727272727273
# Recall:  0.945054945054945
# F-score:  0.9608938547486033
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.7076923076923077
# Recall:  0.9583333333333334
# F-score:  0.8141592920353983

# %% [markdown]
# ### 3.3. Kfold + GridSearch on SVM

# %%
if make_kfold==True:
    result=kfold_gridsearch_function(svm, svm_params, X, Y, K_folds)
    output_function(result, 'SVM', X, Y, X, Y, X_test, y_test)
    
    filename = 'svm_classifier_kfold.pkl'
    pickle.dump(result, open(models_loc+filename, 'wb'))
# Out:
# Best Hyperparameters: {'clf__C': 1.0, 'clf__gamma': 'scale', 'clf__kernel': 'rbf'}
#
# Mean test score: 0.9506475990064046
#
# Std test score: 0.017340909519746817
#
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.9641693811074918
# Recall:  0.9456869009584664
# F-score:  0.9548387096774194
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.7258064516129032
# Recall:  0.9375
# F-score:  0.8181818181818181

# %% [markdown]
# ## 4. Gradient Boosting clf

# %% [markdown]
# ### 4.1 No parameters tuning

# %%
gbc.fit(X_train, y_train)
output_function(gbc, 'Gradient Boosting Classifier', X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Precision/ Recall/ F-score on train set :
#
# Precision:  1.0
# Recall:  1.0
# F-score:  1.0
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.9770114942528736
# Recall:  0.9340659340659341
# F-score:  0.9550561797752809
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.6164383561643836
# Recall:  0.9375
# F-score:  0.743801652892562

# %% [markdown]
# ### 4.2 Grid Search for Gradient Boosting clf (Train/Validation/Test)

# %%
if make_gridsearch==True:
    cv=grid_search_function(gbc, gbc_params, X_train, y_train)
    output_function(cv, 'Gradient Boosting Classifier', X_train, y_train, X_val, y_val, X_test, y_test)
    
    filename = 'gbc_classifier_tvt.pkl'
    pickle.dump(cv, open(models_loc+filename, 'wb'))
# Out:
# {'clf__learning_rate': 0.1, 'clf__max_depth': 7, 'clf__n_estimators': 100, 'clf__subsample': 0.5}
# Precision/ Recall/ F-score on train set :
#
# Precision:  1.0
# Recall:  1.0
# F-score:  1.0
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.9550561797752809
# Recall:  0.9340659340659341
# F-score:  0.9444444444444444
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.5769230769230769
# Recall:  0.9375
# F-score:  0.7142857142857143

# %% [markdown]
# ### 4.3 Kfold + Grid Search (  Gradient Boosting Classifier)

# %%
if make_kfold==True:
    result=kfold_gridsearch_function(gbc, gbc_params, X, Y, K_folds)
    output_function(result, 'Gradient Boosting Classifier', X, Y, X, Y, X_test, y_test)
    
    filename = 'gbc_classifier_kfold.pkl'
    pickle.dump(result, open(models_loc+filename, 'wb'))
# Out:
# Best Hyperparameters: {'clf__learning_rate': 0.1, 'clf__max_depth': 3, 'clf__n_estimators': 100, 'clf__subsample': 0.5}
#
# Mean test score: 0.9509940059404448
#
# Std test score: 0.015211691815050677
#
# Precision/ Recall/ F-score on train set :
#
# Precision:  1.0
# Recall:  0.9936102236421726
# F-score:  0.9967948717948718
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.6268656716417911
# Recall:  0.875
# F-score:  0.7304347826086957

# %% [markdown]
# ## 5. MLPClassifier (Neural Network)

# %% [markdown]
# ### 5.1 No parameters tuning

# %%
# NN
mlpc1= Pipeline([
    ('prep',col_transform), 
    ('clf', MLPClassifier(solver='lbfgs', alpha=1e-5,
                          hidden_layer_sizes=(5, 2), random_state=1))
     ])

mlpc1.fit(X_train, y_train);

# %%
output_function(mlpc1, 'MLPClassifier', X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.9594594594594594
# Recall:  0.9594594594594594
# F-score:  0.9594594594594594
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.9772727272727273
# Recall:  0.945054945054945
# F-score:  0.9608938547486033
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.7333333333333333
# Recall:  0.9166666666666666
# F-score:  0.8148148148148148

# %% [markdown]
# ### 5.2 Grid Search MLPC (Train/ Validation/ test)

# %%
if make_gridsearch==True:
    cv=grid_search_function(mlpc, mlpc_params, X_train, y_train)
    output_function(cv, 'MLPClassifier', X_train, y_train, X_val, y_val, X_test, y_test)

    filename = 'mlpc_classifier_tvt.pkl'
    pickle.dump(cv, open(models_loc+filename, 'wb'))
# Out:
# {'clf__activation': 'tanh', 'clf__alpha': 0.0001, 'clf__hidden_layer_sizes': (10, 30, 10), 'clf__learning_rate': 'constant', 'clf__solver': 'sgd'}
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.9541284403669725
# Recall:  0.9369369369369369
# F-score:  0.9454545454545454
#
#  Precision/ Recall/ F-score on validation set :
#
# Precision:  0.9775280898876404
# Recall:  0.9560439560439561
# F-score:  0.9666666666666667
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.696969696969697
# Recall:  0.9583333333333334
# F-score:  0.8070175438596493

# %%
features
# Out:
# ['Density', 'P_wave', 'Imp', 'V_clay']

# %%
plt.figure(figsize=(12,10))
cor = X_train.corr()
sb.heatmap(cor, annot=True, cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# ### 5.3 Kfold + Grid Search (MLP classifier)

# %%
if make_kfold==True:
    result=kfold_gridsearch_function(mlpc, mlpc_params, X, Y, K_folds)
    output_function(result, 'MLPClassifier', X, Y, X, Y, X_test, y_test)
    
    filename = 'mlpc_classifier_kfold.pkl'
    pickle.dump(result, open(models_loc+filename, 'wb'))
# Out:
# Best Hyperparameters: {'clf__activation': 'relu', 'clf__alpha': 0.05, 'clf__hidden_layer_sizes': (10, 30, 10), 'clf__learning_rate': 'constant', 'clf__solver': 'adam'}
#
# Mean test score: 0.9497938922976241
#
# Std test score: 0.015883065861067882
#
# Precision/ Recall/ F-score on train set :
#
# Precision:  0.9614147909967846
# Recall:  0.9552715654952076
# F-score:  0.9583333333333334
#
#  Precision/ Recall/ F-score on test set :
#
# Precision:  0.6716417910447762
# Recall:  0.9375
# F-score:  0.7826086956521741
